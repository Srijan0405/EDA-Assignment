# %%
import pandas as pd

df = pd.read_csv("netflix_customer_churn.csv")
print("🔍 First 5 rows of the dataset:")
print(df.head())
# Out:
# 🔍 First 5 rows of the dataset:
#                             customer_id  age  gender subscription_type  \
# 0  a9b75100-82a8-427a-a208-72f24052884a   51   Other             Basic
# 1  49a5dfd9-7e69-4022-a6ad-0a1b9767fb5b   47   Other          Standard
# 2  4d71f6ce-fca9-4ff7-8afa-197ac24de14b   27  Female          Standard
# 3  d3c72c38-631b-4f9e-8a0e-de103cad1a7d   53   Other           Premium
# 4  4e265c34-103a-4dbb-9553-76c9aa47e946   56   Other          Standard
#
#    watch_hours  last_login_days   region  device  monthly_fee  churned  \
# 0        14.73               29   Africa      TV         8.99        1
# 1         0.70               19   Europe  Mobile        13.99        1
# 2        16.32               10     Asia      TV        13.99        0
# 3         4.51               12  Oceania      TV        17.99        1
# 4         1.89               13   Africa  Mobile        13.99        1
#
#   payment_method  number_of_profiles  avg_watch_time_per_day favorite_genre
# ...

# %%
#Check for missing/null values
print("\n📌 Missing values in each column:")
print(df.isnull().sum())
# Out:
# 📌 Missing values in each column:
# customer_id               0
# age                       0
# gender                    0
# subscription_type         0
# watch_hours               0
# last_login_days           0
# region                    0
# device                    0
# monthly_fee               0
# churned                   0
# payment_method            0
# number_of_profiles        0
# avg_watch_time_per_day    0
# favorite_genre            0
# dtype: int64

# %%
#Check for unique values in specific categorical columns
categorical_columns = ['gender', 'subscription_type', 'region', 'device', 'payment_method', 'favorite_genre']
print("\n🔍 Unique values in categorical columns:")
for col in categorical_columns:
    print(f"{col}: {df[col].unique()}")
# Out:
# 🔍 Unique values in categorical columns:
# gender: ['Other' 'Female' 'Male']
# subscription_type: ['Basic' 'Standard' 'Premium']
# region: ['Africa' 'Europe' 'Asia' 'Oceania' 'South America' 'North America']
# device: ['TV' 'Mobile' 'Laptop' 'Desktop' 'Tablet']
# payment_method: ['Gift Card' 'Crypto' 'Debit Card' 'PayPal' 'Credit Card']
# favorite_genre: ['Action' 'Sci-Fi' 'Drama' 'Horror' 'Romance' 'Comedy' 'Documentary']

# %%
#Task2 analysis
# 📦 Step 1: Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("netflix_customer_churn.csv")
sns.set(style="whitegrid")

# %%
#Plot distributions for numerical columns
numerical_cols = ['age', 'watch_hours', 'monthly_fee', 'churned']

for col in numerical_cols:
    plt.figure(figsize=(6, 4))
    sns.histplot(data=df, x=col, kde=True, bins=30, color='skyblue')
    plt.title(f'Distribution of {col.capitalize()}', fontsize=14)
    plt.xlabel(col.capitalize())
    plt.ylabel('Frequency')
    plt.tight_layout()
    plt.show()

# %%
#Plot count plots for categorical columns
categorical_cols = [
    'subscription_type', 'gender', 'region',
    'device', 'payment_method', 'favorite_genre'
]

for col in categorical_cols:
    plt.figure(figsize=(8, 4))
    sns.countplot(data=df, x=col, order=df[col].value_counts().index, palette="Set2")
    plt.title(f'Count Plot of {col.replace("_", " ").capitalize()}', fontsize=14)
    plt.xlabel(col.replace("_", " ").capitalize())
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_26212\602527953.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, order=df[col].value_counts().index, palette="Set2")
# C:\Users\shrey\AppData\Local\Temp\ipykernel_26212\602527953.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, order=df[col].value_counts().index, palette="Set2")
# C:\Users\shrey\AppData\Local\Temp\ipykernel_26212\602527953.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
#Bivarte analysis
import seaborn as sns
import matplotlib.pyplot as plt

# %%
categories = ['subscription_type', 'region', 'device']
for col in categories:
    plt.figure(figsize=(12, 4))

# %%
#Average watch hours
plt.subplot(1, 2, 1)
sns.barplot(x=col, y='watch_hours', data=df, estimator='mean', palette='Blues_d')
plt.title(f'Average Watch Hours by {col.capitalize()}')
plt.xticks(rotation=45)
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_26212\1205124591.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=col, y='watch_hours', data=df, estimator='mean', palette='Blues_d')
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'TV'),
#   Text(1, 0, 'Mobile'),
#   Text(2, 0, 'Laptop'),
#   Text(3, 0, 'Desktop'),
#   Text(4, 0, 'Tablet')])

# %%
#Average monthly_fee
plt.subplot(1, 2, 2)
sns.barplot(x=col, y='monthly_fee', data=df, estimator='mean', palette='Greens_d')
plt.title(f'Average Monthly Fee by {col.capitalize()}')
plt.xticks(rotation=45)
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_26212\2951107290.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=col, y='monthly_fee', data=df, estimator='mean', palette='Greens_d')
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'TV'),
#   Text(1, 0, 'Mobile'),
#   Text(2, 0, 'Laptop'),
#   Text(3, 0, 'Desktop'),
#   Text(4, 0, 'Tablet')])

# %%
plt.tight_layout()
plt.show()

# %%
#Plot average avg_watch_time_per_day by favorite_genre
plt.figure(figsize=(10, 5))
sns.barplot(x='favorite_genre', y='avg_watch_time_per_day', data=df, estimator='mean', palette='pastel')
plt.title('Average Daily Watch Time by Favorite Genre')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_26212\56093713.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='favorite_genre', y='avg_watch_time_per_day', data=df, estimator='mean', palette='pastel')

# %%
#Average churn_rate
churn_factors = ['gender', 'region', 'subscription_type', 'payment_method']

for col in churn_factors:
    plt.figure(figsize=(7, 4))
    sns.barplot(x=col, y='churned', data=df, estimator='mean', palette='Set2')
    plt.title(f'Churn Rate by {col.replace("_", " ").capitalize()}')
    plt.ylabel('Churn Rate (0 = No, 1 = Yes)')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_26212\4264240374.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=col, y='churned', data=df, estimator='mean', palette='Set2')
# C:\Users\shrey\AppData\Local\Temp\ipykernel_26212\4264240374.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=col, y='churned', data=df, estimator='mean', palette='Set2')
# C:\Users\shrey\AppData\Local\Temp\ipykernel_26212\4264240374.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
#Corelation analysis
plt.figure(figsize=(10, 6))
numerical_cols = df.select_dtypes(include='number')

# %%
#Look for potential predictors of churn, e.g., watch_hours, last_login_days, monthly_fee.
corr_matrix = numerical_cols.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap of Numerical Features')
plt.show()

# %%
Watch Hours vs. Churn
Customers with lower watch hours tend to churn more frequently.
This suggests engagement is a key predictor of churn.

Subscription Type vs. Churn
Basic users have a higher churn rate compared to Premium users.
Premium users are more likely to retain their subscription.

Region vs. Average Watch Hours
The South region shows the highest average watch hours, followed by North.
These regions may have more engaged users.

Payment Method vs. Churn
Users paying via credit card churn less than those using wallets or UPI.
Auto-renewal might be helping here.

Device Usage Patterns
Users on smart TVs and consoles tend to have higher watch hours but lower churn.
These are typically shared family accounts.

Favorite Genre vs. Engagement
Users whose favorite genre is Drama or Action tend to watch more hours daily than others.
This can guide content recommendations.

Monthly Fee vs. Churn
No strong direct correlation between monthly fee and churn was found, indicating price alone isn’t driving churn.
